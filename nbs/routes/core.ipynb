# %% [markdown]
# # core
#
# > Request helpers for management routes

# %%
#| default_exp routes.core

# %%
#| export
from cjm_transcript_workflow_management.services.management import ManagementService

# Debug flag for route tracing
DEBUG_MANAGEMENT_ROUTES = False

# %% [markdown]
# ## Service Access
#
# Unlike the workflow page-centric libraries that use `StateStore` + `InteractionContext` + session IDs, the management library is stateless. Routes receive `ManagementService` directly via closure — no context loader needed.

# %%
# Verify import
assert ManagementService is not None
print("routes.core imports OK")
# Out:
# routes.core imports OK

# %%
#| hide
import nbdev; nbdev.nbdev_export()
